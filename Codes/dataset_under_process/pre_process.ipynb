# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import shutil
import glob

# %% [markdown]
# # Define interpolate_df function

# %%
def interpolate_df(df):
    """Interpolate DataFrame to fill missing frames between min_frame and max_frame."""
    df['frameNo'] = df['frameNo'].astype(int)
    
    # Check for and handle duplicate 'frameNo' entries
    if df['frameNo'].duplicated().any():
        print("Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.")
        df = df.drop_duplicates(subset='frameNo', keep='first')
    
    min_frame = df['frameNo'].min()
    max_frame = df['frameNo'].max()
    all_frames = range(min_frame, max_frame + 1)
    df.set_index('frameNo', inplace=True)
    df_interpolated = df.reindex(all_frames).interpolate(method='linear')
    df_interpolated.reset_index(inplace=True)
    df_interpolated.rename(columns={'index': 'frameNo'}, inplace=True)
    return df_interpolated

# %% [markdown]
# # Define process_abnormal_tracks function

# %%
def process_abnormal_tracks(abnormal_file):
    """Process abnormal tracks file to extract numbers as a set for lookup."""
    with open(abnormal_file, 'r') as f:
        lines = f.readlines()
    all_abnormal_nums = []
    for line in lines:
        line = line.strip()
        if line.endswith('.csv'):
            nums = line[:-4].split('_')  # Remove '.csv' and split by '_'
            all_abnormal_nums.extend(nums)
    abnormal_set = set(all_abnormal_nums)  # Set for fast lookup
    return abnormal_set

# %% [markdown]
# # Define process_dataset function

# %%
def process_dataset(src_dir, dest_dir, abnormal_file):
    """Process CSV files in src_dir, interpolate them, and segregate into normal/abnormal folders."""
    
    # Clear the destination directory if it already exists
    if os.path.exists(dest_dir):
        shutil.rmtree(dest_dir)
        print(f"Deleted existing directory: {dest_dir}")
    
    # Create destination subdirectories
    os.makedirs(os.path.join(dest_dir, 'normal'), exist_ok=True)
    os.makedirs(os.path.join(dest_dir, 'abnormal'), exist_ok=True)
    print(f"Created directories: {dest_dir}/normal, {dest_dir}/abnormal")
    
    # Get abnormal numbers
    abnormal_set = process_abnormal_tracks(abnormal_file)
    print(f"Loaded {len(abnormal_set)} abnormal numbers from {abnormal_file}")
    
    # Check for CSV files in src_dir
    csv_files = glob.glob(os.path.join(src_dir, '*.csv'))
    print(f"Found {len(csv_files)} CSV files in {src_dir}")
    
    # Process each CSV file
    for csv_file in csv_files:
        filename = os.path.basename(csv_file)
        df = pd.read_csv(csv_file)
        
        # Interpolate the DataFrame
        df_interpolated = interpolate_df(df)
        
        # Extract numbers from filename
        numbers = filename.replace('.csv', '').split('_')
        is_abnormal = any(num in abnormal_set for num in numbers)
        
        # Determine destination based on abnormality
        dest_subdir = 'abnormal' if is_abnormal else 'normal'
        dest_path = os.path.join(dest_dir, dest_subdir, filename)
        df_interpolated.to_csv(dest_path, index=False)
        print(f"Saved interpolated {filename} to {dest_subdir}")

# %% [markdown]
# # Define datasets and process each dataset

# %%
datasets = [
    {
        'src': './sptio-temporal-dataset/10/',
        'dest': './processed/10/',
        'abnormal': './sptio-temporal-dataset/AbnormalTracks_10.txt'
    },
    {
        'src': './sptio-temporal-dataset/11/',
        'dest': './processed/11/',
        'abnormal': './sptio-temporal-dataset/AbnormalTracks_11.txt'
    },
    {
        'src': './sptio-temporal-dataset/12/',
        'dest': './processed/12/',
        'abnormal': './sptio-temporal-dataset/AbnormalTracks_12.txt'
    }
]

for dataset in datasets:
    print(f"\nProcessing dataset: {dataset['dest']}")
    process_dataset(dataset['src'], dataset['dest'], dataset['abnormal'])
# Out:
# Processing dataset: ./processed/10/
# Created directories: ./processed/10//normal, ./processed/10//abnormal
# Loaded 246 abnormal numbers from ./sptio-temporal-dataset/AbnormalTracks_10.txt
# Found 159 CSV files in ./sptio-temporal-dataset/10/
# Saved interpolated 347_.csv to abnormal
# Saved interpolated 748_.csv to abnormal
# Saved interpolated 452_.csv to abnormal
# Saved interpolated 514_549_568_621_704_718_799_820_836_868_878_889_897_899_921_932_946_954_959_.csv to abnormal
# Saved interpolated 143_.csv to abnormal
# Saved interpolated 214_.csv to abnormal
# Saved interpolated 3_.csv to abnormal
# Saved interpolated 7_37_72_128_.csv to abnormal
# Saved interpolated 209_.csv to abnormal
# Saved interpolated 644_.csv to abnormal
# Saved interpolated 88_127_149_184_327_338_400_474_494_604_667_966_.csv to abnormal
# Saved interpolated 798_817_.csv to abnormal
# Saved interpolated 63_.csv to abnormal
# Saved interpolated 589_.csv to abnormal
# Saved interpolated 968_.csv to abnormal
# Saved interpolated 938_.csv to abnormal
# Saved interpolated 51_.csv to abnormal
# Saved interpolated 9_76_111_314_432_471_733_752_805_842_857_887_.csv to abnormal
# Saved interpolated 1_.csv to abnormal
# Saved interpolated 182_.csv to abnormal
# Saved interpolated 958_.csv to abnormal
# Saved interpolated 569_.csv to abnormal
# Saved interpolated 963_.csv to abnormal
# Saved interpolated 390_414_.csv to abnormal
# Saved interpolated 131_.csv to abnormal
# Saved interpolated 265_309_.csv to abnormal
# Saved interpolated 18_.csv to abnormal
# Saved interpolated 430_523_550_555_571_.csv to abnormal
# Saved interpolated 342_.csv to abnormal
# Saved interpolated 227_.csv to abnormal
# Saved interpolated 468_507_529_647_.csv to abnormal
# Saved interpolated 14_40_64_.csv to abnormal
# Saved interpolated 13_30_35_56_62_71_93_98_105_126_165_211_289_295_312_325_365_372_379_391_406_427_.csv to abnormal
# Saved interpolated 732_812_915_.csv to abnormal
# Saved interpolated 174_235_.csv to abnormal
# Saved interpolated 11_77_97_203_226_237_274_.csv to abnormal
# Saved interpolated 4_.csv to abnormal
# Saved interpolated 619_.csv to abnormal
# Saved interpolated 939_944_.csv to abnormal
# Saved interpolated 335_360_403_637_650_707_.csv to abnormal
# Saved interpolated 368_.csv to abnormal
# Saved interpolated 852_872_907_917_.csv to abnormal
# Saved interpolated 486_.csv to abnormal
# Saved interpolated 87_145_156_171_189_198_.csv to abnormal
# Saved interpolated 46_.csv to abnormal
# Saved interpolated 955_.csv to abnormal
# Saved interpolated 99_.csv to abnormal
# Saved interpolated 34_.csv to abnormal
# Saved interpolated 78_.csv to abnormal
# Saved interpolated 823_.csv to abnormal
# Saved interpolated 431_.csv to abnormal
# Saved interpolated 193_.csv to abnormal
# Saved interpolated 81_109_144_177_260_303_343_352_393_457_.csv to abnormal
# Saved interpolated 114_157_223_238_.csv to abnormal
# Saved interpolated 585_.csv to abnormal
# Saved interpolated 22_36_54_142_152_164_192_257_258_276_282_301_334_416_455_487_508_588_597_645_745_811_853_882_916_.csv to abnormal
# Saved interpolated 19_94_.csv to abnormal
# Saved interpolated 82_.csv to abnormal
# Saved interpolated 713_.csv to abnormal
# Saved interpolated 526_634_638_658_.csv to abnormal
# Saved interpolated 397_.csv to abnormal
# Saved interpolated 85_.csv to abnormal
# Saved interpolated 856_.csv to abnormal
# Saved interpolated 225_.csv to abnormal
# Saved interpolated 766_.csv to abnormal
# Saved interpolated 563_590_651_663_.csv to abnormal
# Saved interpolated 370_.csv to abnormal
# Saved interpolated 384_.csv to abnormal
# Saved interpolated 20_47_73_141_229_322_359_420_447_506_577_602_607_699_767_.csv to abnormal
# Saved interpolated 16_.csv to abnormal
# Saved interpolated 32_.csv to abnormal
# Saved interpolated 480_.csv to abnormal
# Saved interpolated 605_.csv to abnormal
# Saved interpolated 232_249_285_304_344_418_.csv to abnormal
# Saved interpolated 825_.csv to abnormal
# Saved interpolated 482_498_527_547_578_599_.csv to abnormal
# Saved interpolated 277_.csv to abnormal
# Saved interpolated 736_791_886_.csv to abnormal
# Saved interpolated 636_694_717_764_.csv to abnormal
# Saved interpolated 92_116_121_.csv to abnormal
# Saved interpolated 620_.csv to abnormal
# Saved interpolated 194_317_.csv to abnormal
# Saved interpolated 826_881_902_929_.csv to abnormal
# Saved interpolated 860_.csv to abnormal
# Saved interpolated 355_.csv to abnormal
# Saved interpolated 609_.csv to abnormal
# Saved interpolated 2_.csv to abnormal
# Saved interpolated 10_.csv to abnormal
# Saved interpolated 511_.csv to abnormal
# Saved interpolated 947_.csv to abnormal
# Saved interpolated 12_689_721_850_.csv to abnormal
# Saved interpolated 789_.csv to abnormal
# Saved interpolated 241_281_375_385_.csv to abnormal
# Saved interpolated 768_.csv to abnormal
# Saved interpolated 641_661_676_684_700_720_.csv to abnormal
# Saved interpolated 151_.csv to abnormal
# Saved interpolated 877_890_949_.csv to abnormal
# Saved interpolated 17_29_90_.csv to abnormal
# Saved interpolated 551_574_.csv to abnormal
# Saved interpolated 43_79_112_120_148_.csv to abnormal
# Saved interpolated 275_.csv to abnormal
# Saved interpolated 21_31_42_134_.csv to abnormal
# Saved interpolated 324_.csv to abnormal
# Saved interpolated 617_624_.csv to abnormal
# Saved interpolated 965_.csv to abnormal
# Saved interpolated 23_75_119_160_231_245_278_308_321_682_708_769_843_864_.csv to abnormal
# Saved interpolated 751_.csv to abnormal
# Saved interpolated 96_.csv to abnormal
# Saved interpolated 660_747_.csv to abnormal
# Saved interpolated 493_544_.csv to abnormal
# Saved interpolated 292_.csv to abnormal
# Saved interpolated 693_.csv to abnormal
# Saved interpolated 106_123_183_207_.csv to abnormal
# Saved interpolated 687_.csv to abnormal
# Saved interpolated 331_351_367_437_.csv to abnormal
# Saved interpolated 220_263_300_.csv to abnormal
# Saved interpolated 970_.csv to abnormal
# Saved interpolated 442_453_.csv to abnormal
# Saved interpolated 964_.csv to abnormal
# Saved interpolated 800_861_957_.csv to abnormal
# Saved interpolated 361_.csv to abnormal
# Saved interpolated 933_.csv to abnormal
# Saved interpolated 378_.csv to abnormal
# Saved interpolated 591_.csv to abnormal
# Saved interpolated 202_283_495_.csv to abnormal
# Saved interpolated 336_404_428_434_492_.csv to abnormal
# Saved interpolated 213_.csv to abnormal
# Saved interpolated 835_.csv to abnormal
# Saved interpolated 536_567_576_691_715_837_.csv to abnormal
# Saved interpolated 675_723_729_739_761_.csv to abnormal
# Saved interpolated 396_.csv to abnormal
# Saved interpolated 255_.csv to abnormal
# Saved interpolated 436_.csv to abnormal
# Saved interpolated 341_501_.csv to abnormal
# Saved interpolated 421_.csv to abnormal
# Saved interpolated 8_.csv to abnormal
# Saved interpolated 5_.csv to abnormal
# Saved interpolated 200_.csv to abnormal
# Saved interpolated 61_.csv to abnormal
# Saved interpolated 332_340_350_388_389_402_410_467_481_515_542_.csv to abnormal
# Saved interpolated 464_477_562_570_622_625_.csv to abnormal
# Saved interpolated 895_.csv to abnormal
# Saved interpolated 444_502_531_.csv to abnormal
# Saved interpolated 758_.csv to abnormal
# Saved interpolated 632_793_888_.csv to abnormal
# Saved interpolated 66_.csv to abnormal
# Saved interpolated 135_228_.csv to abnormal
# Saved interpolated 967_.csv to abnormal
# Saved interpolated 894_923_931_962_.csv to abnormal
# Saved interpolated 6_.csv to abnormal
# Saved interpolated 108_.csv to abnormal
# Saved interpolated 15_52_.csv to abnormal
# Saved interpolated 727_753_774_785_831_.csv to abnormal
# Saved interpolated 554_.csv to abnormal
# Saved interpolated 48_122_132_137_161_172_329_358_408_497_601_755_859_896_940_.csv to abnormal
# Saved interpolated 49_.csv to abnormal
# Saved interpolated 382_423_.csv to abnormal
# Saved interpolated 874_.csv to abnormal
# Saved interpolated 592_626_648_.csv to abnormal
#
# Processing dataset: ./processed/11/
# Created directories: ./processed/11//normal, ./processed/11//abnormal
# Loaded 103 abnormal numbers from ./sptio-temporal-dataset/AbnormalTracks_11.txt
# Found 351 CSV files in ./sptio-temporal-dataset/11/
# Saved interpolated 387_488_.csv to abnormal
# Saved interpolated 437_565_584_.csv to abnormal
# Saved interpolated 466_550_614_702_.csv to abnormal
# Saved interpolated 821_.csv to normal
# Saved interpolated 219_431_.csv to normal
# Saved interpolated 694_.csv to normal
# Saved interpolated 29_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 1346_1375_1401_1420_1503_1548_.csv to normal
# Saved interpolated 318_621_.csv to normal
# Saved interpolated 1494_.csv to normal
# Saved interpolated 1340_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 1302_1347_1348_1411_.csv to abnormal
# Saved interpolated 975_.csv to abnormal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 844_894_899_.csv to normal
# Saved interpolated 3_.csv to normal
# Saved interpolated 1436_.csv to normal
# Saved interpolated 989_.csv to normal
# Saved interpolated 1391_.csv to abnormal
# Saved interpolated 1214_1492_1529_1538_.csv to normal
# Saved interpolated 1592_1630_1658_.csv to normal
# Saved interpolated 1558_.csv to normal
# Saved interpolated 17_350_.csv to normal
# Saved interpolated 63_.csv to abnormal
# Saved interpolated 589_.csv to abnormal
# Saved interpolated 1193_1269_1300_1320_1335_.csv to normal
# Saved interpolated 319_338_362_509_.csv to abnormal
# Saved interpolated 1647_1660_.csv to abnormal
# Saved interpolated 37_138_183_.csv to normal
# Saved interpolated 1665_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated
.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 726_811_860_867_919_960_1012_.csv to normal
# Saved interpolated 1064_.csv to normal
# Saved interpolated 1339_.csv to abnormal
# Saved interpolated 803_.csv to normal
# Saved interpolated 1618_.csv to normal
# Saved interpolated 1473_1484_.csv to normal
# Saved interpolated 1079_1171_.csv to abnormal
# Saved interpolated 533_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 1289_1303_1363_1374_.csv to abnormal
# Saved interpolated 191_212_256_.csv to normal
# Saved interpolated 613_619_674_.csv to normal
# Saved interpolated 1092_1128_.csv to normal
# Saved interpolated 78_.csv to abnormal
# Saved interpolated 1344_.csv to normal
# Saved interpolated 518_548_.csv to abnormal
# Saved interpolated 1091_.csv to normal
# Saved interpolated 791_879_943_.csv to normal
# Saved interpolated 290_.csv to abnormal
# Saved interpolated 22_.csv to normal
# Saved interpolated 314_.csv to abnormal
# Saved interpolated 384_398_.csv to normal
# Saved interpolated 629_.csv to normal
# Saved interpolated 2_435_.csv to normal
# Saved interpolated 1212_.csv to abnormal
# Saved interpolated 1656_1694_.csv to normal
# Saved interpolated 21_.csv to normal
# Saved interpolated 1696_.csv to normal
# Saved interpolated 1530_.csv to normal
# Saved interpolated 890_938_969_1050_.csv to normal
# Saved interpolated 1023_1186_1211_.csv to abnormal
# Saved interpolated 1355_1379_1445_.csv to abnormal
# Saved interpolated 1512_1527_1547_1569_1589_.csv to abnormal
# Saved interpolated 1534_.csv to normal
# Saved interpolated 27_.csv to normal
# Saved interpolated 60_161_169_.csv to normal
# Saved interpolated 542_652_724_.csv to normal
# Saved interpolated 939_.csv to abnormal
# Saved interpolated 1588_.csv to normal
# Saved interpolated 695_823_.csv to normal
# Saved interpolated 1370_.csv to normal
# Saved interpolated 1004_1172_.csv to normal
# Saved interpolated 1476_1602_.csv to abnormal
# Saved interpolated 137_165_274_405_532_.csv to abnormal
# Saved interpolated 492_.csv to normal
# Saved interpolated 1501_.csv to normal
# Saved interpolated 696_756_763_812_856_.csv to normal
# Saved interpolated 1343_1376_1460_.csv to normal
# Saved interpolated 225_.csv to abnormal
# Saved interpolated 1017_.csv to normal
# Saved interpolated 158_262_.csv to normal
# Saved interpolated 498_504_.csv to normal
# Saved interpolated 1664_1680_.csv to abnormal
# Saved interpolated 1427_.csv to normal
# Saved interpolated 35_170_199_.csv to abnormal
# Saved interpolated 9_192_244_.csv to normal
# Saved interpolated 1413_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 13_76_92_.csv to normal
# Saved interpolated 809_.csv to normal
# Saved interpolated 248_261_284_.csv to normal
# Saved interpolated 1368_.csv to normal
# Saved interpolated 980_1040_.csv to normal
# Saved interpolated 1681_1682_.csv to normal
# Saved interpolated 1574_1582_1628_.csv to normal
# Saved interpolated 1470_.csv to normal
# Saved interpolated 1433_.csv to normal
# Saved interpolated 918_941_.csv to abnormal
# Saved interpolated 238_.csv to abnormal
# Saved interpolated 1683_.csv to normal
# Saved interpolated 870_886_.csv to normal
# Saved interpolated 120_.csv to abnormal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated
.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 553_598_602_.csv to abnormal
# Saved interpolated 1471_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 1349_1386_1416_.csv to normal
# Saved interpolated 1278_.csv to normal
# Saved interpolated 531_.csv to normal
# Saved interpolated 955_981_1025_1115_1160_1187_.csv to normal
# Saved interpolated 304_.csv to normal
# Saved interpolated 295_348_.csv to abnormal
# Saved interpolated 1031_1039_.csv to abnormal
# Saved interpolated 1703_.csv to normal
# Saved interpolated 806_836_.csv to normal
# Saved interpolated 280_.csv to normal
# Saved interpolated 1018_1045_.csv to normal
# Saved interpolated 992_.csv to normal
# Saved interpolated 1086_.csv to normal
# Saved interpolated 49_.csv to normal
# Saved interpolated 847_.csv to normal
# Saved interpolated 373_1450_.csv to abnormal
# Saved interpolated 69_.csv to normal
# Saved interpolated 1677_.csv to normal
# Saved interpolated 84_453_.csv to normal
# Saved interpolated 34_135_162_217_.csv to normal
# Saved interpolated 991_1062_.csv to normal
# Saved interpolated 1044_1075_.csv to abnormal
# Saved interpolated 1528_.csv to normal
# Saved interpolated 1150_.csv to abnormal
# Saved interpolated 1015_.csv to abnormal
# Saved interpolated 1425_.csv to abnormal
# Saved interpolated 611_640_704_721_902_.csv to normal
# Saved interpolated 635_693_.csv to normal
#
# Processing dataset: ./processed/12/
# Created directories: ./processed/12//normal, ./processed/12//abnormal
# Loaded 70 abnormal numbers from ./sptio-temporal-dataset/AbnormalTracks_12.txt
# Found 276 CSV files in ./sptio-temporal-dataset/12/
# Saved interpolated 347_.csv to abnormal
# Saved interpolated 11_.csv to normal
# Saved interpolated 548_.csv to normal
# Saved interpolated 337_.csv to normal
# Saved interpolated 1009_1051_1089_.csv to normal
# Saved interpolated 1069_.csv to normal
# Saved interpolated 29_.csv to abnormal
# Saved interpolated 430_.csv to abnormal
# Saved interpolated 435_.csv to abnormal
# Saved interpolated 205_.csv to normal
# Saved interpolated 109_.csv to abnormal
# Saved interpolated 187_198_209_226_.csv to abnormal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 970_971_976_1037_.csv to normal
# Saved interpolated 776_789_.csv to normal
# Saved interpolated 867_891_.csv to normal
# Saved interpolated 91_.csv to normal
# Saved interpolated 989_.csv to normal
# Saved interpolated 173_180_.csv to normal
# Saved interpolated 880_.csv to normal
# Saved interpolated 529_.csv to normal
# Saved interpolated 28_47_70_.csv to normal
# Saved interpolated 778_930_991_.csv to normal
# Saved interpolated 251_.csv to normal
# Saved interpolated 1048_.csv to normal
# Saved interpolated 938_.csv to normal
# Saved interpolated 825_1077_.csv to abnormal
# Saved interpolated 265_503_.csv to abnormal
# Saved interpolated 1003_.csv to normal
# Saved interpolated 51_.csv to abnormal
# Saved interpolated 572_626_632_.csv to normal
# Saved interpolated 1_.csv to normal
# Saved interpolated 182_228_.csv to normal
# Saved interpolated 936_952_982_1088_.csv to normal
# Saved interpolated 879_.csv to normal
# Saved interpolated 30_152_203_211_308_358_451_.csv to abnormal
# Saved interpolated 958_.csv to normal
# Saved interpolated 230_285_.csv to normal
# Saved interpolated 641_.csv to normal
# Saved interpolated 622_.csv to normal
# Saved interpolated 264_.csv to normal
# Saved interpolated 624_727_.csv to normal
# Saved interpolated 74_.csv to normal
# Saved interpolated 20_.csv to normal
# Saved interpolated 26_.csv to normal
# Saved interpolated 882_.csv to normal
# Saved interpolated 861_.csv to normal
# Saved interpolated 272_393_394_424_481_488_534_.csv to abnormal
# Saved interpolated 516_.csv to normal
# Saved interpolated 599_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 596_642_643_.csv to normal
# Saved interpolated 297_318_386_402_.csv to normal
# Saved interpolated 812_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 751_798_804_.csv to normal
# Saved interpolated 926_.csv to normal
# Saved interpolated 765_785_851_.csv to abnormal
# Saved interpolated 859_.csv to normal
# Saved interpolated 474_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 614_743_748_836_.csv to abnormal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 683_876_885_.csv to normal
# Saved interpolated 35_45_67_146_311_493_510_543_589_.csv to abnormal
# Saved interpolated 291_.csv to normal
# Saved interpolated 726_.csv to normal
# Saved interpolated 961_1007_.csv to normal
# Saved interpolated 878_.csv to normal
# Saved interpolated 834_.csv to abnormal
# Saved interpolated 551_.csv to normal
# Saved interpolated 505_.csv to abnormal
# Saved interpolated 478_.csv to abnormal
# Saved interpolated 23_101_.csv to abnormal
# Saved interpolated 437_460_651_.csv to normal
# Saved interpolated 660_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 1000_1042_1065_.csv to normal
# Saved interpolated 752_908_.csv to normal
# Saved interpolated 791_.csv to abnormal
# Saved interpolated 218_.csv to normal
# Saved interpolated 494_.csv to normal
# Saved interpolated 728_.csv to normal
# Saved interpolated 150_.csv to normal
# Saved interpolated 196_.csv to abnormal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 36_57_88_107_124_129_.csv to normal
# Saved interpolated 587_.csv to normal
# Saved interpolated 993_1045_.csv to normal
# Saved interpolated 934_.csv to normal
# Saved interpolated 512_.csv to normal
# Saved interpolated 862_987_.csv to normal
# Saved interpolated 21_154_162_170_193_201_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 630_670_708_710_828_852_.csv to abnormal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 333_387_390_420_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 678_691_700_712_.csv to normal
# Saved interpolated 19_545_922_932_.csv to abnormal
# Saved interpolated 119_145_243_.csv to normal
# Saved interpolated 298_342_407_.csv to normal
# Saved interpolated 996_.csv to normal
# Saved interpolated 1006_.csv to normal
# Saved interpolated 655_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 972_980_1014_1025_.csv to normal
# Saved interpolated 746_.csv to abnormal
# Saved interpolated 290_.csv to normal
# Saved interpolated 314_.csv to normal
# Saved interpolated 1036_.csv to abnormal
# Saved interpolated 260_275_.csv to normal
# Saved interpolated 845_870_.csv to abnormal
# Saved interpolated 202_.csv to abnormal
# Saved interpolated 271_322_438_.csv to normal
# Saved interpolated 208_269_.csv to normal
# Saved interpolated 514_567_.csv to normal
# Saved interpolated 995_1011_.csv to normal
# Saved interpolated 24_.csv to normal
# Saved interpolated 73_84_127_.csv to abnormal
# Saved interpolated 27_.csv to normal
# Saved interpolated 467_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 296_396_397_.csv to abnormal
# Saved interpolated 536_542_564_.csv to normal
# Saved interpolated 417_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 258_294_357_391_409_443_462_495_522_540_561_569_585_693_720_784_1033_1059_.csv to abnormal
# Saved interpolated 623_.csv to normal
# Saved interpolated 280_330_352_.csv to abnormal
# Saved interpolated 939_.csv to normal
# Saved interpolated 232_.csv to normal
# Saved interpolated 855_.csv to normal
# Saved interpolated 31_53_139_238_282_359_439_480_509_539_570_640_704_757_771_914_1035_1068_1086_.csv to abnormal
# Saved interpolated 17_.csv to abnormal
# Saved interpolated 302_320_349_367_388_.csv to normal
# Saved interpolated 71_102_126_.csv to abnormal
# Saved interpolated 4_184_.csv to normal
# Saved interpolated 856_.csv to normal
# Saved interpolated 245_247_252_.csv to normal
# Saved interpolated 957_.csv to normal
# Saved interpolated 965_981_.csv to normal
# Saved interpolated 381_.csv to abnormal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 16_96_97_115_130_167_176_188_.csv to normal
# Saved interpolated 104_131_178_.csv to normal
# Saved interpolated 941_.csv to normal
# Saved interpolated 725_763_.csv to normal
# Saved interpolated 199_.csv to normal
# Saved interpolated 806_1066_.csv to abnormal
# Saved interpolated 458_.csv to normal
# Saved interpolated 747_.csv to abnormal
# Saved interpolated 444_477_.csv to normal
# Saved interpolated 525_.csv to normal
# Saved interpolated 576_.csv to abnormal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 25_179_214_.csv to abnormal
# Saved interpolated 595_.csv to normal
# Saved interpolated 681_701_.csv to normal
# Saved interpolated 48_.csv to normal
# Saved interpolated 12_.csv to normal
# Saved interpolated 362_.csv to abnormal
# Saved interpolated 773_.csv to normal
# Saved interpolated 530_.csv to normal
# Saved interpolated 500_.csv to abnormal
# Saved interpolated 844_.csv to normal
# Saved interpolated 346_364_.csv to normal
# Saved interpolated 620_.csv to normal
# Saved interpolated 370_541_.csv to abnormal
# Saved interpolated 860_.csv to normal
# Saved interpolated 267_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 769_873_887_912_916_.csv to normal
# Saved interpolated 846_1058_1071_.csv to normal
# Saved interpolated 871_886_.csv to normal
# Saved interpolated 2_.csv to normal
# Saved interpolated 13_.csv to normal
# Saved interpolated 964_1080_.csv to normal
# Saved interpolated 7_62_106_159_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 646_676_679_.csv to normal
# Saved interpolated 601_.csv to normal
# Saved interpolated 95_.csv to normal
# Saved interpolated 32_40_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 9_295_315_549_639_782_817_1032_.csv to normal
# Saved interpolated 656_.csv to normal
# Saved interpolated 301_.csv to normal
# Saved interpolated 677_739_772_883_900_1076_.csv to normal
# Saved interpolated 574_.csv to normal
# Saved interpolated 800_924_.csv to abnormal
# Saved interpolated 473_657_.csv to normal
# Saved interpolated 340_.csv to normal
# Saved interpolated 60_.csv to normal
# Saved interpolated 215_.csv to normal
# Saved interpolated 903_963_.csv to normal
# Saved interpolated 112_.csv to abnormal
# Saved interpolated 811_.csv to normal
# Saved interpolated 14_75_.csv to normal
# Saved interpolated 688_.csv to normal
# Saved interpolated 502_.csv to abnormal
# Saved interpolated 305_360_378_.csv to normal
# Saved interpolated 22_87_.csv to normal
# Saved interpolated 143_163_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 287_313_329_338_339_373_377_399_406_433_453_461_476_483_524_.csv to normal
# Saved interpolated 928_.csv to normal
# Saved interpolated 520_544_566_631_.csv to normal
# Saved interpolated 719_.csv to normal
# Saved interpolated 890_899_.csv to normal
# Saved interpolated 910_.csv to abnormal
# Saved interpolated 197_.csv to normal
# Saved interpolated 283_.csv to normal
# Saved interpolated 1050_1082_.csv to normal
# Saved interpolated 276_.csv to abnormal
# Saved interpolated 72_94_147_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 317_334_344_354_423_434_440_.csv to normal
# Saved interpolated 1057_.csv to normal
# Saved interpolated 611_.csv to normal
# Saved interpolated 66_92_.csv to abnormal
# Saved interpolated 244_.csv to normal
# Saved interpolated 745_.csv to normal
# Saved interpolated 86_172_.csv to normal
# Saved interpolated 1060_.csv to normal
# Saved interpolated 421_448_578_593_648_658_711_762_814_918_935_985_1079_.csv to normal
# Saved interpolated 110_113_.csv to normal
# Saved interpolated 553_662_.csv to normal
# Saved interpolated 805_816_.csv to normal
# Saved interpolated 1008_.csv to normal
# Saved interpolated 454_.csv to normal
# Saved interpolated 602_.csv to normal
# Saved interpolated 526_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 33_68_76_103_121_186_195_216_235_239_241_250_270_471_472_484_485_497_498_511_605_637_665_674_740_793_.csv to abnormal
# Saved interpolated 644_709_724_738_760_779_.csv to abnormal
# Saved interpolated 527_.csv to abnormal
# Saved interpolated 907_.csv to normal
# Saved interpolated 584_.csv to normal
# Saved interpolated 588_.csv to abnormal
# Saved interpolated 5_653_755_770_.csv to normal
# Saved interpolated 116_.csv to normal
# Saved interpolated 246_.csv to normal
# Saved interpolated 221_223_.csv to normal
# Saved interpolated 403_412_.csv to normal
# Saved interpolated 591_.csv to abnormal
# Saved interpolated 356_413_.csv to normal
# Saved interpolated 831_937_994_1004_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 947_949_969_975_1010_1024_.csv to normal
# Saved interpolated 89_.csv to normal
# Saved interpolated 376_613_.csv to abnormal
# Saved interpolated 3_55_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 666_761_797_807_872_923_929_950_1056_1062_1083_.csv to abnormal
# Saved interpolated 255_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 523_649_654_.csv to normal
# Saved interpolated 581_.csv to abnormal
# Saved interpolated 8_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 42_65_69_82_.csv to normal
# Saved interpolated 546_628_.csv to normal
# Saved interpolated 1043_.csv to normal
# Saved interpolated 675_699_.csv to normal
# Saved interpolated 190_350_.csv to normal
# Saved interpolated 604_.csv to normal
# Saved interpolated 15_.csv to abnormal
# Saved interpolated 224_.csv to abnormal
# Saved interpolated 366_.csv to abnormal
# Saved interpolated 117_.csv to abnormal
# Saved interpolated 895_.csv to normal
# Saved interpolated 850_884_927_988_990_1019_.csv to abnormal
# Saved interpolated 633_.csv to normal
# Saved interpolated 369_.csv to abnormal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 10_61_63_.csv to normal
# Saved interpolated 889_921_.csv to normal
# Saved interpolated 165_220_233_240_254_.csv to normal
# Saved interpolated 206_.csv to normal
# Saved interpolated 508_.csv to abnormal
# Saved interpolated 707_722_.csv to normal
# Saved interpolated 34_39_.csv to normal
# Saved interpolated 18_191_310_365_446_.csv to abnormal
# Saved interpolated 200_262_.csv to normal
# Saved interpolated 944_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 663_803_840_847_898_906_.csv to normal
# Saved interpolated 6_.csv to abnormal
# Saved interpolated 565_.csv to normal
# Saved interpolated 456_.csv to normal
# Saved interpolated 166_.csv to abnormal
# Saved interpolated 998_.csv to normal
# Saved interpolated 531_.csv to normal
# Saved interpolated 533_968_.csv to normal
# Saved interpolated 1041_1067_.csv to abnormal
# Saved interpolated 615_706_.csv to abnormal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 600_610_619_635_659_.csv to normal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 108_156_171_174_219_253_279_304_306_324_.csv to abnormal
# Saved interpolated 775_.csv to normal
# Saved interpolated 249_.csv to abnormal
# Warning: Duplicate frameNo found in the DataFrame. Dropping duplicates.
# Saved interpolated 703_830_837_.csv to normal
# Saved interpolated 532_555_580_672_.csv to abnormal
